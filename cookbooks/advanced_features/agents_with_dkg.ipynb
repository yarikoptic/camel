# %% [markdown]
# # 📊 Dynamic Knowledge Graph Construction for Financial Report with CAMEL

# %% [markdown]
# You can also check this cookbook in colab [here](https://drive.google.com/file/d/19EWVOVZl_nVCs0ERr6IEaxiXHGPObYS9/view?usp=sharing)
#
# <div class="align-center">
#   <a href="https://www.camel-ai.org/"><img src="https://i.postimg.cc/KzQ5rfBC/button.png"width="150"></a>
#   <a href="https://discord.camel-ai.org"><img src="https://i.postimg.cc/L4wPdG9N/join-2.png"  width="150"></a></a>
#
# ⭐ <i>Star us on [*Github*](https://github.com/camel-ai/camel), join our [*Discord*](https://discord.camel-ai.org) or follow our [*X*](https://x.com/camelaiorg)
# </div>

# %% [markdown]
# This notebook demonstrates how to build a dynamic knowledge graph using CAMEL's Knowledge Graph Agent and Neo4j. The knowledge graph is constructed by parsing PDF documents, extracting entities and relationships, and storing them in a Neo4j database. The graph is then queried to retrieve time-based relationships.
#
# In this notebook, you'll explore:
#
# - **CAMEL**: A powerful multi-agent framework that enables the construction of knowledge graphs from unstructured data.
# - **Neo4j**: A graph database used to store and query the knowledge graph.
# - **Together and SambaVerse Models**: Large language models used to generate the knowledge graph from parsed documents.
# - **Deduplication**: Techniques to ensure the uniqueness of nodes and relationships in the graph.
#
# This setup not only demonstrates a practical application of AI-driven knowledge graph construction but also provides a flexible framework that can be adapted to other real-world scenarios requiring dynamic graph generation and querying.

# %% [markdown]
# ## 📦 Installation

# %% [markdown]
# First, install the CAMEL package with all its dependencies:
# Second, make sure that Neo4j is running and accessible from your local machine.

# %%
pip install "camel-ai[rag]==0.2.22"

# %% [markdown]
# ## 🚀 Launch Service
#
# Start Neo4j service in the background((using Ubuntu as an example))

# %%
neo4j start

# %% [markdown]
# ## 🔑 Setting Up API Keys

# %% [markdown]
# You'll need to set up your API keys for Together and SambaVerse. This ensures that the tools can interact with external services securely.

# %%
import os
import dotenv
import colorama
from getpass import getpass

dotenv.load_dotenv()

# Prompt for the TogetherAI API key securely
together_api_key = getpass('Enter Together API key: ')
os.environ["TOGETHER_API_KEY"] = together_api_key

# Prompt for the SambanovaAI API key securely
sambanova_api_key = getpass('Enter Sambanova API key: ')
os.environ["SAMBA_API_KEY"] = sambanova_api_key

# Prompt for the OpenAI API key securely
openai_api_key = getpass('Enter OpenAI API key: ')
os.environ["OPENAI_API_KEY"] = openai_api_key

print(
    colorama.Fore.GREEN
    + "✅ Loading environment variables successfully."
    + colorama.Fore.RESET
)
# Out:
# ✅ Loading environment variables successfully.

# %% [markdown]
# ## 🛠️ Setting Up Neo4j

# %% [markdown]
# To store and query the knowledge graph, you'll need a Neo4j instance. If you don't have one, you can set up a local instance or use a cloud service like Neo4j Aura.
#
# 1. **Local Setup**: Download and install Neo4j Desktop from [here](https://neo4j.com/download/).
# 2. **Cloud Setup**: Sign up for Neo4j Aura [here](https://neo4j.com/cloud/aura/).
#
# Once you have your Neo4j instance running, set up the connection details:

# %%
# Prompt for Neo4j securely
os.environ["NEO4J_URI"] = getpass('Enter NEO4J_URI: ')
os.environ["NEO4J_USERNAME"] = getpass('Enter NEO4J_USERNAME: ')
os.environ["NEO4J_PASSWORD"] = getpass('Enter NEO4J_PASSWORD: ')

# %% [markdown]
# ## 🧠 Setting Up the Knowledge Graph Agent

# %% [markdown]
# We will use CAMEL's Knowledge Graph Agent to parse PDF documents, extract entities and relationships, and store them in the Neo4j database. The agent uses Together and SambaVerse models for graph generation.
#
# Replace the file path in the code below with your own data directory path
# example_file_dir = Path("/home/mi/daily/fin-camel/pdf_tmp")

# %%
from pathlib import Path

from tqdm import tqdm

from camel.agents import KnowledgeGraphAgent
from camel.configs import TogetherAIConfig, SambaCloudAPIConfig, ChatGPTConfig
from camel.embeddings import MistralEmbedding
from camel.loaders import UnstructuredIO
from camel.models import ModelFactory
from camel.storages import Neo4jGraph
from camel.types import ModelPlatformType, ModelType

# Set up Neo4j connection
neo4j_graph = Neo4jGraph(
    url=os.environ["NEO4J_URI"],
    username=os.environ["NEO4J_USERNAME"],
    password=os.environ["NEO4J_PASSWORD"],
)

# Clear the Neo4j database before starting
print("Clearing Neo4j database...")
neo4j_graph.query("MATCH (n) DETACH DELETE n")
print("✅ Neo4j database cleared successfully.")

# Use TogetherAI model
together_api_model = ModelFactory.create(
    model_platform=ModelPlatformType.TOGETHER,
    model_type=ModelType.TOGETHER_LLAMA_3_1_70B,
    model_config_dict=TogetherAIConfig(temperature=0.2).as_dict(),
)

# Use Samba Verse model
sambaverse_api_model = ModelFactory.create(
    model_platform=ModelPlatformType.SAMBA,
    model_type="Meta-Llama-3.1-405B-Instruct",
    model_config_dict=SambaCloudAPIConfig(max_tokens=2048).as_dict(),
    api_key=os.environ["SAMBA_API_KEY"],
    url="https://api.sambanova.ai/v1",
)

# Use OpenAI model
openai_model = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI,
    model_type=ModelType.GPT_4O_MINI,
    model_config_dict=ChatGPTConfig().as_dict(),
)

# Set up the example files
example_file_dir = Path("/home/mi/daily/fin-camel/pdf_kvue")
assert (
    example_file_dir.exists()
), "Please set the correct path to the example pdf files."

example_pdf_files = list(example_file_dir.glob("*.pdf"))
print(f"Found {len(example_pdf_files)} PDF files.")

# UnstructuredIO is a tool to parse and chunk the documents.
uio = UnstructuredIO()

# Together is a model to generate the knowledge graph.
together_kg_agent = KnowledgeGraphAgent(model=together_api_model)

# Samba Verse model is a model to generate the knowledge graph.
llama_405b_kg_agent = KnowledgeGraphAgent(model=sambaverse_api_model)

# OpenAI model is a model to generate the knowledge graph.
openai_kg_agent = KnowledgeGraphAgent(model=openai_model)
# Out:
# Clearing Neo4j database...
# ✅ Neo4j database cleared successfully.
# Found 4 PDF files.

# %% [markdown]
# ## 🏗️ Building the Knowledge Graph

# %% [markdown]
# The ID normalization process ensures compliant Neo4j identifiers by sanitizing input strings (replacing non-alphanumeric characters with underscores), ensuring no numeric prefixes, splitting/cleaning components, and applying SHA-1 hashing truncation to enforce a maximum 64-character limit while preserving uniqueness and readability.

# %%
import hashlib

def normalize_name(name: str, max_length: int = 64) -> str:
    """Normalize the label name to comply with Neo4j's naming rules"""
    # Remove special characters and replace spaces with underscores
    normalized = "".join(c if c.isalnum() else "_" for c in name)
    # Ensure it does not start with a digit
    if normalized[0].isdigit():
        normalized = "id_" + normalized
    # Remove extra underscores
    normalized = "_".join(filter(None, normalized.split("_")))

    # If the VID is too long, use a hash function to generate a fixed-length VID
    if len(normalized) > max_length:
        # Use the SHA-1 hash function to generate a fixed-length VID
        hash_value = hashlib.sha1(normalized.encode()).hexdigest()
        # Truncate to max_length
        normalized = hash_value[:max_length]

    return normalized

# %% [markdown]
# Prompt we use for dynamic knowledge graph generation, which has timestamp in element.

# %%
custom_prompt = """
You are tasked with extracting nodes and relationships from given content and structuring them into Node and Relationship objects. Here's the outline of what you need to do:

Content Extraction: You should be able to process input content and identify entities mentioned within it.

Entities can be any noun phrases or concepts that represent distinct entities in the context of the given content.

Node Extraction: For each identified entity, you should create a Node object. Each Node object should have a unique identifier (id) and a type (type).

Additional properties associated with the node can also be extracted and stored.

Relationship Extraction: You should identify relationships between entities mentioned in the content. For each relationship, create a Relationship object.

A Relationship object should have a subject (subj) and an object (obj) which are Node objects representing the entities involved in the relationship.

Each relationship should also have a type (type), and additional properties if applicable.

Timestamp Requirement: For each relationship, you must assign a timestamp that reflects the time the relationship was established or mentioned based on the context of the provided content.

If the timestamp cannot be derived from the content, assign None instead. The timestamp format should be: YYYY-MM-DDTHH:MM:SS (e.g., "2025-02-13T19:41:48").

Output Formatting: The extracted nodes and relationships should be formatted as instances of the provided Node and Relationship classes.

Ensure that the extracted data adheres to the structure defined by the classes. Output the structured data in a format that can be easily validated against the provided code.

Instructions for you:

Read the provided content thoroughly.
Identify distinct entities mentioned in the content and categorize them as nodes.
Determine relationships between these entities and represent them as directed relationships, including a timestamp for each relationship (or None if not applicable).
Provide the extracted nodes and relationships in the specified format below.
Example for you:

Example Content: "John works at XYZ Corporation since 2020. He is a software engineer. The company is located in New York City."

Expected Output:

Nodes:

Node(id='John', type='Person')
Node(id='XYZ Corporation', type='Organization')
Node(id='New York City', type='Location')
Relationships:

Relationships:

Relationship(subj=Node(id='John', type='Person'), obj=Node(id='XYZ Corporation', type='Organization'), type='WorksAt', timestamp='2025-02-13T19:41:48')
Relationship(subj=Node(id='John', type='Person'), obj=Node(id='New York City', type='Location'), type='ResidesIn', timestamp='2025-02-13T19:47:39')

===== TASK ===== Please extract nodes and relationships from the given content and structure them into Node and Relationship objects.

{task}
"""

# %% [markdown]
# Here we iterate over each PDF file in the example_pdf_files list. For each file, it parses the content and chunks the elements based on titles, ensuring that each chunk does not exceed 2048 characters.Within the first loop, we process each chunked element. We run it through the openai_kg_agent to generate graph elements. Then, we iterate over each node in the graph element to adjust its type and normalize its ID.After processing the nodes, we prepare a list of node IDs to be used for embedding. This list will be used in the next step for deduplication.

# %%
from tqdm import tqdm

node_texts = []
graph_element_list = []
for file in example_pdf_files:
    elements = uio.parse_file_or_url(str(file))
    chunk_elements = uio.chunk_elements(
        elements, chunk_type="chunk_by_title", max_characters=2048
    )

    for element in tqdm(chunk_elements):
        graph_element = openai_kg_agent.run(
            element, parse_graph_elements=True, prompt=custom_prompt
        )

        # Add processing logic to rename 'Date' type
        for node in graph_element.nodes:
            if node.type == "Date":
                node.type = "TimePoint"  # or another name that is not a reserved keyword
            elif node.type == "{self.type}":
                node.type = "Node"  # Set default type
            node.id = normalize_name(
                node.id, max_length=64
            )  # Ensure VID length does not exceed 64

        # Prepare texts for embedding
        node_texts.extend([node.id for node in graph_element.nodes])
        graph_element_list.append(graph_element)
# Out:
# 100%|██████████| 7/7 [01:27<00:00, 12.55s/it]
# 100%|██████████| 398/398 [1:09:14<00:00, 10.44s/it]
# 100%|██████████| 183/183 [31:56<00:00, 10.47s/it]
# 100%|██████████| 7/7 [00:56<00:00,  8.05s/it]

# %% [markdown]
# Perform internal deduplication on the node texts using the deduplicate_internally function. We set a threshold of 0.65 and specify the embedding strategy as "top1". The result provides unique IDs of the nodes.

# %%
from camel.utils import deduplicate_internally
from camel.embeddings import SentenceTransformerEncoder

# Perform internal deduplication
sentence_encoder = SentenceTransformerEncoder(model_name='intfloat/e5-large-v2')
deduplication_result = deduplicate_internally(
    texts=node_texts,
    threshold=0.65,
    embedding_instance=sentence_encoder,
    strategy="top1",
    batch_size=10,  # Adjust batch size as needed
)

# Get unique nodes
unique_node_ids = {node_texts[i] for i in deduplication_result.unique_ids}

# %% [markdown]
# Filter relationships to include only those where both the subject and object nodes are unique, as determined by the deduplication step.

# %%
unique_relationships = []
for graph_unit in graph_element_list:
    for rel in graph_unit.relationships:
        if (
            rel.subj.id in unique_node_ids
            and rel.obj.id in unique_node_ids
        ):
            unique_relationships.append(rel)

# %% [markdown]
# After running the program above, access results by navigating to https://console-preview.neo4j.io/tools/query in your web browser. Sign in using your Neo4j credentials (as specified in the configuration file), and you'll see the **knowledge graph with timestamps** displayed as shown below.
# ![Peek 2025-02-25 10-20.gif](data:image/gif;base64,...)
# ![2025-02-24 17-37-17屏幕截图.png](data:image/png;base64,...)
# ![2025-02-24 17-36-39屏幕截图.png](data:image/png;base64,...)

# %% [markdown]
# Add the unique relationships to a Neo4j graph. For each relationship, we generate a timestamp and add the triplet to the graph.

# %%
import time

for rel in unique_relationships:
    current_time = time.strftime("%Y-%m-%dT%H:%M:%S", time.localtime())
    timestamp = rel.timestamp if rel.timestamp is not None else current_time
    neo4j_graph.add_triplet(
        subj=rel.subj.id,
        obj=rel.obj.id,
        rel=rel.type,
        timestamp=timestamp,
    )

# %% [markdown]
# ## 🔍 Querying the Knowledge Graph

# %% [markdown]
# Now that the knowledge graph is built, we can query it to retrieve time-based relationships.

# %%
# Query all triplets
all_triplets = neo4j_graph.get_triplet()
if all_triplets:
    for triplet in all_triplets:
        print(
            f"Subject: {triplet['subj']}, Object: {triplet['obj']}, "
            f"Relationship: {triplet['rel']}, "
            f"Timestamp: {triplet['timestamp']}"
        )
else:
    print("No triplets found in the database.")
# Out:
# Subject: Kenvue, Object: Johnson_Johnson, Relationship: PARTOF, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: Johnson_Johnson, Relationship: SEPARATION, Timestamp: 2023-08-01T00:00:00
# Subject: Kenvue, Object: Johnson_Johnson, Relationship: INCORPORATEDASSUBSIDIARYOF, Timestamp: 2022-02-01T00:00:00
# Subject: Kenvue_Inc, Object: Johnson_Johnson, Relationship: NETINVESTMENTFROM, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: Johnson_Johnson, Relationship: SEPARATEDFROM, Timestamp: 2023-08-01T00:00:00
# Subject: Mr_Wolk, Object: Johnson_Johnson, Relationship: SERVESASCFO, Timestamp: 2018-01-01T00:00:00
# Subject: Kenvue, Object: Johnson_Johnson, Relationship: OWNEDBY, Timestamp: 2024-01-24T00:00:00
# Subject: Kenvue, Object: Johnson_Johnson, Relationship: SPINOFFFROM, Timestamp: 2023-11-12T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue_Inc, Relationship: SPLITOFF, Timestamp: 2023-05-04T00:00:00
# Subject: PricewaterhouseCoopers_LLP, Object: Kenvue_Inc, Relationship: AUDITOROF, Timestamp: 2024-03-01T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue_Inc, Relationship: ENTEREDINTOAGREEMENT, Timestamp: 2023-05-03T00:00:00
# Subject: Thibaut_Mongon, Object: Kenvue_Inc, Relationship: SIGNEDBY, Timestamp: 2024-03-01T00:00:00
# Subject: Paul_Ruh, Object: Kenvue_Inc, Relationship: SIGNEDBY, Timestamp: 2024-03-01T00:00:00
# Subject: Seemantini_Godbole, Object: Kenvue_Inc, Relationship: SIGNEDBY, Timestamp: 2024-03-01T00:00:00
# Subject: Melanie_L_Healey, Object: Kenvue_Inc, Relationship: SIGNEDBY, Timestamp: 2024-03-01T00:00:00
# Subject: Betsy_D_Holden, Object: Kenvue_Inc, Relationship: SIGNEDBY, Timestamp: 2024-03-01T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue_Inc, Relationship: COMPLETEDSPLITOFF, Timestamp: 2023-05-04T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue_Inc, Relationship: OWNERSHIPSTAKE, Timestamp: 2023-07-24T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue, Relationship: PARENTCOMPANY, Timestamp: 2022-02-01T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue, Relationship: COMPLETEDTRANSFER, Timestamp: 2023-04-01T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue, Relationship: EXCHANGEOFFER, Timestamp: 2023-07-01T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue, Relationship: COMPLETEDEXCHANGE, Timestamp: 2023-08-01T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue, Relationship: COMPLETEDTRANSFEROFASSETS, Timestamp: 2023-04-01T00:00:00
# Subject: Founder_Shares, Object: Kenvue, Relationship: GRANTEDON, Timestamp: 2023-10-02T00:00:00
# Subject: Company, Object: Kenvue, Relationship: ESTABLISHEDAS, Timestamp: 2023-12-31T00:00:00
# Subject: J_J, Object: Kenvue, Relationship: INCURREDCOSTSFOR, Timestamp: 2023-12-31T00:00:00
# Subject: J_J, Object: Kenvue, Relationship: REPLACEDBY, Timestamp: 2023-08-23T00:00:00
# Subject: Company, Object: Kenvue, Relationship: APPROVEDBY, Timestamp: 2023-10-02T00:00:00
# Subject: Compensation_Human_Capital_Committee, Object: Kenvue, Relationship: GRANTS, Timestamp: 2023-08-25T00:00:00
# Subject: Johnson_Johnson, Object: Kenvue, Relationship: SEPARATIONCOMPLETED, Timestamp: 2023-08-01T00:00:00
# Subject: Jan_Meurer, Object: Kenvue, Relationship: MEMBEROFLEADERSHIP, Timestamp: 2023-05-01T00:00:00
# Subject: NEOs, Object: Kenvue, Relationship: PLAYEDROLEIN, Timestamp: 2023-01-01T00:00:00
# Subject: NEOs, Object: Kenvue, Relationship: RECEIVEDINCENTIVEAWARDS, Timestamp: 2023-12-01T00:00:00
# Subject: J_J, Object: Kenvue, Relationship: APPROVEDCONVERSION, Timestamp: 2023-05-03T00:00:00
# Subject: Mr_Lawson, Object: Kenvue, Relationship: RECEIVESBENEFITS, Timestamp: 2023-01-01T00:00:00
# Subject: J_J, Object: Kenvue, Relationship: TAXFREEDISPOSITION, Timestamp: 2023-08-01T00:00:00
# Subject: J_J, Object: Kenvue, Relationship: TRANSFERREDINTELLECTUALPROPERTY, Timestamp: 2023-05-03T00:00:00
# Subject: J_J, Object: Kenvue, Relationship: PROVIDES, Timestamp: 2023-05-03T00:00:00
# Subject: J_J, Object: Kenvue, Relationship: CREDITS, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue_CHCC, Object: Kenvue, Relationship: ESTABLISHEDIN, Timestamp: 2023-01-01T00:00:00
# Subject: Thibaut_Mongon, Object: Kenvue, Relationship: DIRECTORSINCE, Timestamp: 2023-05-01T00:00:00
# Subject: Seemantini_Godbole, Object: Kenvue, Relationship: DIRECTORSINCE, Timestamp: 2023-05-01T00:00:00
# Subject: Ms_Healey, Object: Kenvue, Relationship: SERVESASDIRECTOR, Timestamp: 2023-05-01T00:00:00
# Subject: Mr_Wolk, Object: Kenvue, Relationship: SERVESASDIRECTOR, Timestamp: 2023-05-01T00:00:00
# Subject: Mr_Lawson, Object: Kenvue, Relationship: RECEIVEDINCENTIVE, Timestamp: 2023-12-31T00:00:00
# Subject: Ms_Xie, Object: Kenvue, Relationship: RECEIVEDINCENTIVE, Timestamp: 2023-12-31T00:00:00
# Subject: Carlton_Lawson, Object: Kenvue, Relationship: BENEFICIALOWNER, Timestamp: 2024-03-25T00:00:00
# Subject: Thibaut_Mongon, Object: Kenvue, Relationship: BENEFICIALOWNER, Timestamp: 2024-03-25T00:00:00
# Subject: Paul_Ruh, Object: Kenvue, Relationship: BENEFICIALOWNER, Timestamp: 2024-03-25T00:00:00
# Subject: Melanie_L_Healey, Object: Kenvue, Relationship: BENEFICIALOWNER, Timestamp: 2024-03-25T00:00:00
# Subject: Betsy_D_Holden, Object: Kenvue, Relationship: BENEFICIALOWNER, Timestamp: 2024-03-25T00:00:00
# Subject: Ellie_Bing_Xie, Object: Kenvue, Relationship: BENEFICIALOWNER, Timestamp: 2024-03-25T00:00:00
# Subject: Joseph_J_Wolk, Object: Kenvue, Relationship: BENEFICIALOWNER, Timestamp: 2024-03-25T00:00:00
# Subject: J_J, Object: Kenvue, Relationship: SEPARATION, Timestamp: 2023-01-01T00:00:00
# Subject: Carlton_Lawson, Object: Kenvue, Relationship: SERVESAS, Timestamp: 2024-01-01T00:00:00
# Subject: Paul_Ruh, Object: Kenvue, Relationship: SERVESAS, Timestamp: 2023-05-01T00:00:00
# Subject: Luani_Alvarado, Object: Kenvue, Relationship: SERVESAS, Timestamp: 2023-05-01T00:00:00
# Subject: Charmaine_England, Object: Kenvue, Relationship: SERVESAS, Timestamp: 2024-01-01T00:00:00
# Subject: Jan_Meurer, Object: Kenvue, Relationship: SERVESAS, Timestamp: 2024-01-01T00:00:00
# Subject: Matthew_Orlando, Object: Kenvue, Relationship: SERVESAS, Timestamp: 2023-05-01T00:00:00
# Subject: Meredith_Stevens, Object: Kenvue, Relationship: SERVESAS, Timestamp: 2023-05-01T00:00:00
# Subject: Ellie_Bing_Xie, Object: Kenvue, Relationship: SERVESAS, Timestamp: 2023-05-01T00:00:00
# Subject: Paul_Ruh, Object: Kenvue, Relationship: MEMBEROF, Timestamp: 2023-05-01T00:00:00
# Subject: Matthew_Orlando, Object: Kenvue, Relationship: MEMBEROF, Timestamp: 2023-05-01T00:00:00
# Subject: J_J, Object: Kenvue, Relationship: ENTEREDINTOAGREEMENT, Timestamp: 2023-05-03T00:00:00
# Subject: Founder_Shares, Object: Kenvue, Relationship: GRANTEDTO, Timestamp: 2023-10-02T00:00:00
# Subject: Kenvue, Object: id_2024, Relationship: VALUATIONYEAR, Timestamp: 2024-11-08T00:00:00
# Subject: Engagement_Awards, Object: id_2024, Relationship: EARNEDIN, Timestamp: 2024-01-01T00:00:00
# Subject: Kenvue, Object: id_2024, Relationship: CONDUCTSASSESSMENTIN, Timestamp: 2024-01-01T00:00:00
# Subject: Kenvue, Object: id_2023, Relationship: BECAMEINDEPENDENT, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: id_2023, Relationship: DEBUTYEAR, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: id_2023, Relationship: GENERATEDSALESIN, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: id_2023, Relationship: REPORTSFORYEAR, Timestamp: 2023-01-02T00:00:00
# Subject: Kenvue, Object: id_2023, Relationship: ESTABLISHEDIN, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: id_2023, Relationship: PERFORMANCEYEAR, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue_CHCC, Object: id_2023, Relationship: DETERMINEDINCENTIVEDESIGN, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue_CHCC, Object: id_2023, Relationship: APPROVEDPERFORMANCEACHIEVEMENTLEVEL, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: id_2023, Relationship: INCURSCOSTS, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: id_2023, Relationship: PROJECTSREVENUEGROWTH, Timestamp: 2023-11-12T00:00:00
# Subject: Kenvue, Object: North_America, Relationship: OPERATESIN, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: Asia_Pacific, Relationship: OPERATESIN, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: Middle_East, Relationship: OPERATESIN, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: Latin_America, Relationship: OPERATESIN, Timestamp: 2023-01-01T00:00:00
# Subject: Carlton_Lawson, Object: Latin_America, Relationship: RESPONSIBLEFOR, Timestamp: 2024-01-01T00:00:00
# Subject: Johnson_Johnson, Object: Consumer_Health_Business, Relationship: OWNS, Timestamp: 2021-11-01T00:00:00
# Subject: Johnson_Johnson, Object: Consumer_Health_Business, Relationship: INTENDSTOSEPARATE, Timestamp: 2021-11-01T00:00:00
# Subject: J_J, Object: Consumer_Health_Business, Relationship: TRANSFER, Timestamp: 2023-04-04T00:00:00
# Subject: Company, Object: Consumer_Health_Business, Relationship: HASSEGMENT, Timestamp: 2023-01-01T00:00:00
# Subject: J_J, Object: Consumer_Health_Business, Relationship: ANNOUNCEDSEPARATION, Timestamp: 2021-11-12T00:00:00
# Subject: Kenvue, Object: Delaware, Relationship: INCORPORATEDIN, Timestamp: 2022-02-23T00:00:00
# Subject: Kenvue, Object: KVUE, Relationship: HASTICKERSYMBOL, Timestamp: 2023-05-01T00:00:00
# Subject: Kenvue, Object: KVUE, Relationship: TICKERSYMBOLFOR, Timestamp: 2023-05-01T00:00:00
# Subject: Kenvue, Object: Diversity_Equity_and_Inclusion, Relationship: COMMITSTO, Timestamp: 2023-12-31T00:00:00
# Subject: Over_the_Counter_Monograph_Safety_Innovation_and_Reform_Act, Object: FDA, Relationship: ENACTEDBY, Timestamp: 2020-03-01T00:00:00
# Subject: Nonprescription_Drugs_Advisory_Committee, Object: FDA, Relationship: ADVISES, Timestamp: 2023-09-01T00:00:00
# Subject: Johnson_Johnson, Object: Johnson_Johnson_Consumer_Inc, Relationship: ENTEREDINTOAGREEMENT, Timestamp: 2023-04-03T00:00:00
# Subject: Johnson_Johnson_Consumer_Inc, Object: Neutrogena, Relationship: RECALLS, Timestamp: 2021-07-01T00:00:00
# Subject: Johnson_Johnson_Consumer_Inc, Object: Aveeno, Relationship: RECALLS, Timestamp: 2021-07-01T00:00:00
# Subject: FDA, Object: Company, Relationship: CONSIDERSINPUTFROM, Timestamp: 2023-09-01T00:00:00
# Subject: J_J, Object: Company, Relationship: TRANSFERREDEQUITYINTERESTSTO, Timestamp: 2023-12-31T00:00:00
# Subject: December_31_2023, Object: Company, Relationship: FISCALPERIODEND, Timestamp: 2023-12-31T00:00:00
# Subject: January_1_2023, Object: Company, Relationship: FISCALPERIODEND, Timestamp: 2023-01-01T00:00:00
# Subject: January_2_2022, Object: Company, Relationship: FISCALPERIODEND, Timestamp: 2022-01-02T00:00:00
# Subject: Management, Object: Company, Relationship: BELIEVES, Timestamp: 2022-01-02T00:00:00
# Subject: J_J, Object: Company, Relationship: REPAIDLOAN, Timestamp: 2023-05-08T00:00:00
# Subject: North_America, Object: Company, Relationship: NETSALESATTRIBUTION, Timestamp: 2023-12-31T00:00:00
# Subject: Asia_Pacific, Object: Company, Relationship: NETSALESATTRIBUTION, Timestamp: 2023-12-31T00:00:00
# Subject: Latin_America, Object: Company, Relationship: NETSALESATTRIBUTION, Timestamp: 2023-12-31T00:00:00
# Subject: Proxy_Statement, Object: Company, Relationship: DESCRIBES, Timestamp: 2024-01-01T00:00:00
# Subject: Self_Care, Object: Company, Relationship: PARTOF, Timestamp: 2023-01-01T00:00:00
# Subject: Skin_Health_and_Beauty, Object: Company, Relationship: PARTOF, Timestamp: 2023-01-01T00:00:00
# Subject: Essential_Health, Object: Company, Relationship: PARTOF, Timestamp: 2023-01-01T00:00:00
# Subject: Fiscal_Twelve_Months_Ended_December_31_2023, Object: Company, Relationship: REPORTS, Timestamp: 2023-12-31T00:00:00
# Subject: Fiscal_Twelve_Months_Ended_January_1_2023, Object: Company, Relationship: REPORTS, Timestamp: 2023-01-01T00:00:00
# Subject: Fiscal_Twelve_Months_Ended_January_2_2022, Object: Company, Relationship: REPORTS, Timestamp: 2022-01-02T00:00:00
# Subject: Company, Object: U_S_District_Court_for_the_District_of_New_Jersey, Relationship: DEFENDSAGAINST, Timestamp: 2023-10-01T00:00:00
# Subject: Company, Object: U_S_District_Court_for_the_District_of_New_Jersey, Relationship: INVOLVEDINLITIGATION, Timestamp: 2023-10-01T00:00:00
# Subject: Company, Object: Canada, Relationship: OPERATESIN, Timestamp: 2023-09-01T00:00:00
# Subject: Company, Object: Canada, Relationship: INVOLVEDINLITIGATION, Timestamp: 2023-09-01T00:00:00
# Subject: J_J, Object: Canada, Relationship: DISCONTINUEDIN, Timestamp: 2020-01-01T00:00:00
# Subject: Kenvue, Object: J_J, Relationship: PARTOF, Timestamp: 2023-08-23T00:00:00
# Subject: Company, Object: J_J, Relationship: PARTOF, Timestamp: 2023-08-23T00:00:00
# Subject: Consumer_Health_Business, Object: J_J, Relationship: NOLONGERPARTICIPATESIN, Timestamp: 2023-04-04T00:00:00
# Subject: Consumer_Health_Business_Transfer, Object: J_J, Relationship: DISTRIBUTESTO, Timestamp: 2023-05-08T00:00:00
# Subject: Kenvue, Object: J_J, Relationship: IPOCOMPLETED, Timestamp: 2023-05-08T00:00:00
# Subject: Company, Object: J_J, Relationship: OPERATEDASSEGMENTOF, Timestamp: 2023-04-04T00:00:00
# Subject: Kenvue, Object: J_J, Relationship: ENTEREDINTOAGREEMENT, Timestamp: 2023-05-03T00:00:00
# Subject: Kenvue, Object: J_J, Relationship: ENTEREDINTO, Timestamp: 2023-05-03T00:00:00
# Subject: Company, Object: J_J, Relationship: ENTEREDINTO, Timestamp: 2023-04-04T00:00:00
# Subject: Company, Object: J_J, Relationship: PARTICIPATEDIN, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: J_J, Relationship: LOANEDFUNDSTHROUGH, Timestamp: 2023-04-05T00:00:00
# Subject: Company, Object: J_J, Relationship: LENDS, Timestamp: 2023-04-05T00:00:00
# Subject: lease_liabilities, Object: J_J, Relationship: RELATEDTO, Timestamp: 2023-12-31T00:00:00
# Subject: Tax_Matters_Agreement, Object: J_J, Relationship: GOVERNS, Timestamp: 2023-05-03T00:00:00
# Subject: Kenvue, Object: J_J, Relationship: BECAMEINDEPENDENTFROM, Timestamp: 2023-08-23T00:00:00
# Subject: Kenvue, Object: J_J, Relationship: CEASEDRELATIONSHIPWITH, Timestamp: 2023-08-23T00:00:00
# Subject: Kenvue, Object: J_J, Relationship: SEPARATIONFROM, Timestamp: 2023-05-01T00:00:00
# Subject: The_Company, Object: J_J, Relationship: SEPARATIONFROM, Timestamp: 2023-12-31T00:00:00
# Subject: Shareholder_Engagement, Object: J_J, Relationship: SEPARATIONFROM, Timestamp: 2023-08-01T00:00:00
# Subject: Kenvue, Object: J_J, Relationship: SEPARATEDFROM, Timestamp: 2023-08-01T00:00:00
# Subject: Board, Object: J_J, Relationship: SEPARATEDFROM, Timestamp: 2023-05-01T00:00:00
# Subject: NEOs, Object: J_J, Relationship: RECEIVEDINCENTIVEAWARDS, Timestamp: 2023-02-01T00:00:00
# Subject: Kenvue, Object: J_J, Relationship: ENTERSINTOAGREEMENT, Timestamp: 2023-05-03T00:00:00
# Subject: J_J, Object: United_States, Relationship: DISCONTINUEDIN, Timestamp: 2020-01-01T00:00:00
# Subject: Russia_Ukraine_War, Object: Foreign_currency_volatility, Relationship: CAUSES, Timestamp: 2022-01-01T00:00:00
# Subject: Kenvue, Object: id_1_914_581_851, Relationship: HASSHARESOUTSTANDING, Timestamp: 2024-02-23T00:00:00
# Subject: Kenvue, Object: February_14_2024, Relationship: RECORDDATEFORNEXTDIVIDEND, Timestamp: 2024-02-14T00:00:00
# Subject: Kenvue_Inc, Object: December_31_2023, Relationship: STOCKTRADINGEND, Timestamp: 2023-12-31T00:00:00
# Subject: Net_Sales, Object: December_31_2023, Relationship: REPORTEDON, Timestamp: 2023-12-31T00:00:00
# Subject: Cost_of_Sales, Object: December_31_2023, Relationship: REPORTEDON, Timestamp: 2023-12-31T00:00:00
# Subject: Self_Care_Segment, Object: December_31_2023, Relationship: REPORTEDON, Timestamp: 2023-12-31T00:00:00
# Subject: Stock_based_Compensation_Expense, Object: December_31_2023, Relationship: REPORTEDON, Timestamp: 2023-12-31T00:00:00
# Subject: Self_Care_Segment, Object: December_31_2023, Relationship: FISCALPERIODENDED, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: December_31_2023, Relationship: FISCALENDDATE, Timestamp: 2023-12-31T00:00:00
# Subject: Essential_Health_Segment, Object: December_31_2023, Relationship: FISCALENDDATE, Timestamp: 2023-12-31T00:00:00
# Subject: Cash_and_Cash_Equivalents, Object: December_31_2023, Relationship: ASOF, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue_Inc, Object: December_31_2023, Relationship: FINANCIALSTATEMENTDATE, Timestamp: 2023-12-31T00:00:00
# Subject: KENVUE_INC, Object: December_31_2023, Relationship: FINANCIALSTATEMENTDATE, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: December_31_2023, Relationship: CHANGEEFFECTIVEDATE, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: December_31_2023, Relationship: ACCOUNTSPAYABLEBALANCE, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: December_31_2023, Relationship: HASOUTSTANDINGBALANCES, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: December_31_2023, Relationship: REPORTSON, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: December_31_2023, Relationship: REPORTSFORDATE, Timestamp: 2023-12-31T00:00:00
# Subject: Stock_Options, Object: December_31_2023, Relationship: UNRECOGNIZEDEXPENSEREPORTEDON, Timestamp: 2023-12-31T00:00:00
# Subject: id_2023, Object: December_31_2023, Relationship: ENDSFISCALYEAR, Timestamp: 2023-12-31T00:00:00
# Subject: January_2_2022, Object: December_31_2023, Relationship: FISCALPERIODEND, Timestamp: 2022-01-02T00:00:00
# Subject: Fiscal_Year_2023, Object: December_31_2023, Relationship: ENDEDON, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: December_31_2023, Relationship: REPORTEDBALANCESHEETASOF, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: December_31_2023, Relationship: FINANCIALREPORTINGDATE, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: December_31_2023, Relationship: DETERMINEDASOF, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: December_31_2023, Relationship: FINANCIALREPORTINGPERIOD, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue_2023_Plan, Object: December_31_2023, Relationship: ESTABLISHEDON, Timestamp: 2023-12-31T00:00:00
# Subject: NEOs, Object: December_31_2023, Relationship: TERMINATIONEFFECTIVEASOF, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: Separation, Relationship: COMPLETEDSEPARATION, Timestamp: 2023-08-01T00:00:00
# Subject: Kenvue, Object: Separation, Relationship: FOCUSAREA, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: Summit_New_Jersey, Relationship: HEADQUARTERSLOCATION, Timestamp: 2023-04-20T00:00:00
# Subject: Company, Object: Summit_New_Jersey, Relationship: HASLEASEIN, Timestamp: 2023-04-20T00:00:00
# Subject: Net_Income, Object: Fiscal_Year_2023, Relationship: REPORTEDIN, Timestamp: 2023-12-31T00:00:00
# Subject: Deferred_Income_Taxes, Object: Fiscal_Year_2023, Relationship: REPORTEDIN, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: Fiscal_Year_2023, Relationship: ADOPTSSTANDARDASOF, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: Fiscal_Year_2023, Relationship: REPORTSON, Timestamp: 2022-01-02T00:00:00
# Subject: Kenvue_Inc, Object: Net_Sales, Relationship: REPORTS, Timestamp: 2023-12-31T00:00:00
# Subject: Fiscal_Year_2023, Object: Net_Sales, Relationship: REPORTS, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: Net_Sales, Relationship: REPRESENTS, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: Fiscal_Twelve_Months_Ended_December_31_2023, Relationship: RESULTSFOR, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: Fiscal_Twelve_Months_Ended_January_1_2023, Relationship: RESULTSFOR, Timestamp: 2023-01-01T00:00:00
# Subject: Fiscal_Twelve_Months_Ended_December_31_2023, Object: Other_operating_income_net, Relationship: REPORTEDMETRIC, Timestamp: 2023-12-31T00:00:00
# Subject: Net_Sales, Object: January_1_2023, Relationship: REPORTEDON, Timestamp: 2023-01-01T00:00:00
# Subject: Cost_of_Sales, Object: January_1_2023, Relationship: REPORTEDON, Timestamp: 2023-01-01T00:00:00
# Subject: Self_Care_Segment, Object: January_1_2023, Relationship: REPORTEDON, Timestamp: 2023-01-01T00:00:00
# Subject: Stock_based_Compensation_Expense, Object: January_1_2023, Relationship: REPORTEDON, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: January_1_2023, Relationship: FISCALSTARTDATE, Timestamp: 2023-01-01T00:00:00
# Subject: Essential_Health_Segment, Object: January_1_2023, Relationship: FISCALSTARTDATE, Timestamp: 2023-01-01T00:00:00
# Subject: Fiscal_Twelve_Months, Object: January_1_2023, Relationship: ENDSON, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue_Inc, Object: January_1_2023, Relationship: FINANCIALSTATEMENTDATE, Timestamp: 2023-01-01T00:00:00
# Subject: KENVUE_INC, Object: January_1_2023, Relationship: FINANCIALSTATEMENTDATE, Timestamp: 2023-01-01T00:00:00
# Subject: Fiscal_Year_2023, Object: January_1_2023, Relationship: INCLUDEDIN, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: January_1_2023, Relationship: PRIORCHANGEDATE, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: January_1_2023, Relationship: ACCOUNTSPAYABLEBALANCE, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: January_1_2023, Relationship: REPORTSON, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: January_1_2023, Relationship: REPORTSFORDATE, Timestamp: 2023-01-01T00:00:00
# Subject: id_2023, Object: January_1_2023, Relationship: ENDSFISCALYEAR, Timestamp: 2023-01-01T00:00:00
# Subject: January_2_2022, Object: January_1_2023, Relationship: FISCALPERIODEND, Timestamp: 2022-01-02T00:00:00
# Subject: Company, Object: January_1_2023, Relationship: REPORTEDBALANCESHEETASOF, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue_Inc, Object: Cost_of_Sales, Relationship: REPORTS, Timestamp: 2023-12-31T00:00:00
# Subject: Fiscal_Twelve_Months_Ended_January_1_2023, Object: Fiscal_Twelve_Months_Ended_January_2_2022, Relationship: COMPAREDWITH, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: Founder_Shares, Relationship: APPROVEDON, Timestamp: 2023-08-25T00:00:00
# Subject: Compensation_Human_Capital_Committee, Object: Founder_Shares, Relationship: APPROVED, Timestamp: 2023-08-25T00:00:00
# Subject: Kenvue, Object: Founder_Shares, Relationship: GRANTEDTO, Timestamp: 2023-10-02T00:00:00
# Subject: P_Ruh, Object: Founder_Shares, Relationship: GRANTED, Timestamp: 2023-10-01T00:00:00
# Subject: M_Stevens, Object: Founder_Shares, Relationship: GRANTED, Timestamp: 2023-10-01T00:00:00
# Subject: J_J, Object: Cash_and_Cash_Equivalents, Relationship: RECEIVESDISTRIBUTION, Timestamp: 2023-05-08T00:00:00
# Subject: Kenvue, Object: U_S_Federal_consolidated_income_tax_return, Relationship: FILES, Timestamp: 2023-08-23T00:00:00
# Subject: Company, Object: U_S_Federal_consolidated_income_tax_return, Relationship: FILES, Timestamp: 2023-08-23T00:00:00
# Subject: Company, Object: GILTI, Relationship: CHANGEDACCOUNTINGPRINCIPLE, Timestamp: 2022-01-02T00:00:00
# Subject: Company, Object: GILTI, Relationship: CHANGEDACCOUNTINGMETHOD, Timestamp: 2023-07-01T00:00:00
# Subject: J_J, Object: GILTI, Relationship: ELECTEDDEFERREDEFFECTS, Timestamp: 2018-01-01T00:00:00
# Subject: Company, Object: Self_Care, Relationship: HASSEGMENT, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: Self_Care, Relationship: PERFORMSTESTON, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: Skin_Health_and_Beauty, Relationship: HASSEGMENT, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: Skin_Health_and_Beauty, Relationship: PERFORMSTESTON, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: Essential_Health, Relationship: HASSEGMENT, Timestamp: 2023-01-01T00:00:00
# Subject: Company, Object: Essential_Health, Relationship: PERFORMSTESTON, Timestamp: 2023-01-01T00:00:00
# Subject: Fiscal_Year_2023, Object: Essential_Health, Relationship: INCLUDES, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue_Inc, Object: Net_Income, Relationship: REPORTS, Timestamp: 2023-12-31T00:00:00
# Subject: Stock_based_Compensation_Expense, Object: January_2_2022, Relationship: REPORTEDON, Timestamp: 2022-01-02T00:00:00
# Subject: KENVUE_INC, Object: January_2_2022, Relationship: FINANCIALSTATEMENTDATE, Timestamp: 2022-01-02T00:00:00
# Subject: Fiscal_Year_2023, Object: January_2_2022, Relationship: INCLUDEDIN, Timestamp: 2022-01-02T00:00:00
# Subject: Company, Object: January_2_2022, Relationship: PRIORCHANGEDATE, Timestamp: 2022-01-02T00:00:00
# Subject: Company, Object: January_2_2022, Relationship: PREVIOUSFISCALDATE, Timestamp: 2022-01-02T00:00:00
# Subject: PSUs, Object: January_2_2022, Relationship: UNRECOGNIZEDEXPENSEREPORTEDON, Timestamp: 2022-01-02T00:00:00
# Subject: id_2022, Object: January_2_2022, Relationship: ENDSFISCALYEAR, Timestamp: 2022-01-02T00:00:00
# Subject: Company, Object: January_2_2022, Relationship: REPORTEDBALANCESHEETASOF, Timestamp: 2022-01-02T00:00:00
# Subject: Kenvue, Object: id_13_8_billion, Relationship: DISTRIBUTIONTO, Timestamp: 2023-05-08T00:00:00
# Subject: J_J, Object: Consolidated_Financial_Statements, Relationship: REPORTS, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: Consolidated_Financial_Statements, Relationship: DERIVEDFROM, Timestamp: 2023-04-04T00:00:00
# Subject: J_J, Object: Consolidated_Financial_Statements, Relationship: INCLUDEDIN, Timestamp: 2023-04-04T00:00:00
# Subject: Company, Object: Consolidated_Financial_Statements, Relationship: IMPACTEDBYCHANGE, Timestamp: 2023-12-31T00:00:00
# Subject: Audit_Committee, Object: Consolidated_Financial_Statements, Relationship: REVIEWS, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: Consolidated_Balance_Sheets, Relationship: REPORTS, Timestamp: 2023-12-31T00:00:00
# Subject: lease_liabilities, Object: Consolidated_Balance_Sheets, Relationship: INCLUDEDIN, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: Consolidated_Balance_Sheets, Relationship: RECOGNIZEDRECEIVABLE, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: Consolidated_Balance_Sheets, Relationship: RECOGNIZEDPAYABLE, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: Assets, Relationship: TOTALASSETS, Timestamp: 2023-12-31T00:00:00
# Subject: January_2_2022, Object: id_348_million, Relationship: AMORTIZATIONEXPENSE, Timestamp: 2022-01-02T00:00:00
# Subject: Johnson_Johnson, Object: Tax_Matters_Agreement, Relationship: ENTEREDINTO, Timestamp: 2023-05-03T00:00:00
# Subject: Kenvue, Object: Tax_Matters_Agreement, Relationship: ENTEREDINTO, Timestamp: 2023-05-03T00:00:00
# Subject: J_J, Object: Tax_Matters_Agreement, Relationship: ENTEREDINTO, Timestamp: 2023-05-03T00:00:00
# Subject: J_J, Object: Tax_Matters_Agreement, Relationship: GOVERNS, Timestamp: 2023-05-03T00:00:00
# Subject: Kenvue, Object: Kenvue_2023_Plan, Relationship: HASPLAN, Timestamp: 2023-08-23T00:00:00
# Subject: Company, Object: Kenvue_2023_Plan, Relationship: APPROVED, Timestamp: 2023-03-01T00:00:00
# Subject: J_J, Object: Kenvue_2023_Plan, Relationship: APPROVED, Timestamp: 2023-05-01T00:00:00
# Subject: January_1_2023, Object: Kenvue_2023_Plan, Relationship: STARTDATE, Timestamp: 2023-01-01T00:00:00
# Subject: December_31_2023, Object: Kenvue_2023_Plan, Relationship: ENDDATE, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: Stock_based_compensation_expense, Relationship: RECOGNIZEDEXPENSE, Timestamp: 2023-12-31T00:00:00
# Subject: J_J, Object: Stock_based_compensation_expense, Relationship: REVERSEDEXPENSE, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: PSUs, Relationship: RECOGNIZEDCOMPENSATIONCOSTS, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: PSUs, Relationship: GRANTEDTO, Timestamp: 2023-10-02T00:00:00
# Subject: Board, Object: Compensation_Human_Capital_Committee, Relationship: EVALUATES, Timestamp: 2023-12-01T00:00:00
# Subject: Kenvue, Object: Stock_Options, Relationship: GRANTEDTO, Timestamp: 2023-10-02T00:00:00
# Subject: Thibaut_Mongon, Object: Stock_Options, Relationship: GRANTED, Timestamp: 2022-02-14T00:00:00
# Subject: Thibaut_Mongon, Object: Stock_Options, Relationship: RECEIVED, Timestamp: 2023-02-13T00:00:00
# Subject: Paul_Ruh, Object: Stock_Options, Relationship: RECEIVED, Timestamp: 2023-02-13T00:00:00
# Subject: Ellie_Bing_Xie, Object: Stock_Options, Relationship: RECEIVED, Timestamp: 2023-02-13T00:00:00
# Subject: Carlton_Lawson, Object: Stock_Options, Relationship: RECEIVES, Timestamp: 2023-02-13T00:00:00
# Subject: Meredith_Stevens, Object: Stock_Options, Relationship: RECEIVES, Timestamp: 2023-02-13T00:00:00
# Subject: Ellie_Bing_Xie, Object: Stock_Options, Relationship: RECEIVES, Timestamp: 2023-02-13T00:00:00
# Subject: Carlton_Lawson, Object: Stock_Options, Relationship: HAS, Timestamp: 2023-02-13T00:00:00
# Subject: Kenvue_CHCC, Object: id_2022, Relationship: APPROVEDENGAGEMENTAWARDS, Timestamp: 2022-01-01T00:00:00
# Subject: Johnson_Johnson, Object: Employee_Matters_Agreement, Relationship: ENTEREDINTO, Timestamp: 2023-05-03T00:00:00
# Subject: Kenvue, Object: Employee_Matters_Agreement, Relationship: ENTEREDINTO, Timestamp: 2023-05-03T00:00:00
# Subject: J_J, Object: Employee_Matters_Agreement, Relationship: ADDRESSES, Timestamp: 2023-05-03T00:00:00
# Subject: Kenvue, Object: Intellectual_Property_Agreement, Relationship: ENTEREDINTO, Timestamp: 2023-05-03T00:00:00
# Subject: J_J, Object: Intellectual_Property_Agreement, Relationship: GOVERNS, Timestamp: 2023-05-03T00:00:00
# Subject: J_J, Object: Transition_Services_Agreement, Relationship: PROVIDESSERVICES, Timestamp: 2023-05-03T00:00:00
# Subject: Kenvue, Object: Transition_Services_Agreement, Relationship: ENTERSINTO, Timestamp: 2023-05-03T00:00:00
# Subject: Company, Object: Kenvue_IPO, Relationship: COMPLETED, Timestamp: 2023-05-08T00:00:00
# Subject: Company, Object: Kenvue_IPO, Relationship: CLAIMEDBENEFITSUNTIL, Timestamp: 2023-12-31T00:00:00
# Subject: The_Company, Object: Kenvue_IPO, Relationship: SEPARATIONFROM, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: Foreign_Tax_Credits, Relationship: UTILIZES, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: May_8_2023, Relationship: IPOCOMPLETEDON, Timestamp: 2023-05-08T00:00:00
# Subject: Company, Object: Trade_Receivables, Relationship: INCLUDES, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: Cash_Flow_Hedge_Portfolio, Relationship: RECORDSCHANGEIN, Timestamp: 2023-12-31T00:00:00
# Subject: Company, Object: id_30_year_Bonds, Relationship: ISSUED, Timestamp: 2023-01-01T00:00:00
# Subject: Fiscal_Year_2023, Object: Cough_Cold_and_Allergy, Relationship: INCLUDES, Timestamp: 2023-12-31T00:00:00
# Subject: Fiscal_Year_2023, Object: Women_s_Health, Relationship: INCLUDES, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue_Inc, Object: SEC, Relationship: FILEDWITH, Timestamp: 2023-03-30T00:00:00
# Subject: Kenvue, Object: SEC, Relationship: FILEDWITH, Timestamp: 2024-03-01T00:00:00
# Subject: Kenvue_Inc, Object: Deutsche_Bank_Trust_Company_Americas, Relationship: TRUSTEEOF, Timestamp: 2023-03-22T00:00:00
# Subject: Kenvue_Inc, Object: Executive_Severance_Pay_Plan, Relationship: FILEDAS, Timestamp: 2023-11-03T00:00:00
# Subject: Kenvue_Inc, Object: Exhibit_10_7, Relationship: FILEDAS, Timestamp: 2023-11-03T00:00:00
# Subject: Kenvue_Inc, Object: Exhibit_10_7, Relationship: FILEDASEXHIBIT, Timestamp: 2023-05-08T00:00:00
# Subject: Kenvue_Inc, Object: Exhibit_10_8, Relationship: FILEDAS, Timestamp: 2023-11-03T00:00:00
# Subject: Kenvue_Inc, Object: Exhibit_10_8, Relationship: FILEDASEXHIBIT, Timestamp: 2023-05-08T00:00:00
# Subject: Kenvue_Inc, Object: Exhibit_10_18, Relationship: FILEDAS, Timestamp: 2023-11-03T00:00:00
# Subject: Johnson_Johnson, Object: Separation_Agreement, Relationship: ENTEREDINTO, Timestamp: 2023-05-03T00:00:00
# Subject: Kenvue, Object: Separation_Agreement, Relationship: CONTAINSPROVISIONS, Timestamp: 2023-05-03T00:00:00
# Subject: Employment_Agreement, Object: Carlton_Lawson, Relationship: BETWEEN, Timestamp: 2022-06-22T00:00:00
# Subject: Shareholder_Engagement, Object: Board, Relationship: OVERSIGHT, Timestamp: 2023-08-01T00:00:00
# Subject: Board, Object: Nominating_Governance_Sustainability_Committee, Relationship: CONDUCTS, Timestamp: 2023-12-01T00:00:00
# Subject: Board, Object: Board_Culture_Charter, Relationship: ADOPTS, Timestamp: 2023-12-01T00:00:00
# Subject: Board, Object: Audit_Committee, Relationship: EVALUATES, Timestamp: 2023-12-01T00:00:00
# Subject: Board, Object: Executive_Committee, Relationship: EVALUATES, Timestamp: 2023-12-01T00:00:00
# Subject: Shareholder_Engagement, Object: Institutional_Holders, Relationship: OUTREACHTO, Timestamp: 2023-08-01T00:00:00
# Subject: Kenvue_CHCC, Object: NEOs, Relationship: EVALUATEDCOMPENSATION, Timestamp: 2023-01-01T00:00:00
# Subject: J_J, Object: NEOs, Relationship: SETCOMPENSATION, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue_CHCC, Object: NEOs, Relationship: ESTABLISHEDBASESALARIES, Timestamp: 2023-01-01T00:00:00
# Subject: Kenvue, Object: NEOs, Relationship: COMPENSATES, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue_CHCC, Object: February_2023, Relationship: GRANTEDLONGTERMINCENTIVEAWARDS, Timestamp: 2023-02-01T00:00:00
# Subject: Kenvue_CHCC, Object: December_2023, Relationship: APPROVEDLONGTERMINCENTIVEGRANT, Timestamp: 2023-12-01T00:00:00
# Subject: Kenvue, Object: P_Ruh, Relationship: RECEIVEDGRANT, Timestamp: 2023-12-01T00:00:00
# Subject: P_Ruh, Object: Engagement_Awards, Relationship: RECEIVED, Timestamp: 2023-09-01T00:00:00
# Subject: M_Stevens, Object: Engagement_Awards, Relationship: RECEIVED, Timestamp: 2023-09-01T00:00:00
# Subject: PSUs, Object: Organic_Net_Sales, Relationship: PERFORMANCEMEASURE, Timestamp: 2026-12-31T00:00:00
# Subject: Mr_Lawson, Object: Switzerland, Relationship: RELOCATEDTO, Timestamp: 2023-01-01T00:00:00
# Subject: Thibaut_Mongon, Object: Annual_Incentive, Relationship: RECEIVED, Timestamp: 2023-02-13T00:00:00
# Subject: Thibaut_Mongon, Object: Founder_PSUs, Relationship: GRANTED, Timestamp: 2023-10-02T00:00:00
# Subject: Thibaut_Mongon, Object: Founder_PSUs, Relationship: RECEIVED, Timestamp: 2023-10-02T00:00:00
# Subject: Paul_Ruh, Object: Founder_PSUs, Relationship: RECEIVED, Timestamp: 2023-10-02T00:00:00
# Subject: Ellie_Bing_Xie, Object: Founder_PSUs, Relationship: RECEIVED, Timestamp: 2023-10-02T00:00:00
# Subject: Carlton_Lawson, Object: Founder_PSUs, Relationship: RECEIVES, Timestamp: 2023-10-02T00:00:00
# Subject: Meredith_Stevens, Object: Founder_PSUs, Relationship: RECEIVES, Timestamp: 2023-10-02T00:00:00
# Subject: Ellie_Bing_Xie, Object: Founder_PSUs, Relationship: RECEIVES, Timestamp: 2023-10-02T00:00:00
# Subject: Thibaut_Mongon, Object: Founder_Stock_Options, Relationship: GRANTED, Timestamp: 2023-10-02T00:00:00
# Subject: Thibaut_Mongon, Object: Founder_Stock_Options, Relationship: RECEIVED, Timestamp: 2023-10-02T00:00:00
# Subject: Paul_Ruh, Object: Founder_Stock_Options, Relationship: RECEIVED, Timestamp: 2023-10-02T00:00:00
# Subject: Ellie_Bing_Xie, Object: Founder_Stock_Options, Relationship: RECEIVED, Timestamp: 2023-10-02T00:00:00
# Subject: Carlton_Lawson, Object: Founder_Stock_Options, Relationship: RECEIVES, Timestamp: 2023-10-02T00:00:00
# Subject: Meredith_Stevens, Object: Founder_Stock_Options, Relationship: RECEIVES, Timestamp: 2023-10-02T00:00:00
# Subject: Ellie_Bing_Xie, Object: Founder_Stock_Options, Relationship: RECEIVES, Timestamp: 2023-10-02T00:00:00
# Subject: Thibaut_Mongon, Object: Dec_2023_PSUs, Relationship: GRANTED, Timestamp: 2023-12-07T00:00:00
# Subject: Thibaut_Mongon, Object: Dec_2023_PSUs, Relationship: RECEIVED, Timestamp: 2023-12-07T00:00:00
# Subject: Paul_Ruh, Object: Dec_2023_PSUs, Relationship: RECEIVED, Timestamp: 2023-12-07T00:00:00
# Subject: Ellie_Bing_Xie, Object: Dec_2023_PSUs, Relationship: RECEIVED, Timestamp: 2023-12-07T00:00:00
# Subject: Carlton_Lawson, Object: Dec_2023_PSUs, Relationship: RECEIVES, Timestamp: 2023-12-07T00:00:00
# Subject: Meredith_Stevens, Object: Dec_2023_PSUs, Relationship: RECEIVES, Timestamp: 2023-12-07T00:00:00
# Subject: Ellie_Bing_Xie, Object: Dec_2023_PSUs, Relationship: RECEIVES, Timestamp: 2023-12-07T00:00:00
# Subject: Thibaut_Mongon, Object: Dec_2023_RSUs, Relationship: GRANTED, Timestamp: 2023-12-07T00:00:00
# Subject: Thibaut_Mongon, Object: Dec_2023_RSUs, Relationship: RECEIVED, Timestamp: 2023-12-07T00:00:00
# Subject: Paul_Ruh, Object: Dec_2023_RSUs, Relationship: RECEIVED, Timestamp: 2023-12-07T00:00:00
# Subject: Ellie_Bing_Xie, Object: Dec_2023_RSUs, Relationship: RECEIVED, Timestamp: 2023-12-07T00:00:00
# Subject: Carlton_Lawson, Object: Dec_2023_RSUs, Relationship: RECEIVES, Timestamp: 2023-12-07T00:00:00
# Subject: Meredith_Stevens, Object: Dec_2023_RSUs, Relationship: RECEIVES, Timestamp: 2023-12-07T00:00:00
# Subject: Ellie_Bing_Xie, Object: Dec_2023_RSUs, Relationship: RECEIVES, Timestamp: 2023-12-07T00:00:00
# Subject: Thibaut_Mongon, Object: Healthcare_Coverage, Relationship: RECEIVES, Timestamp: 2023-12-31T00:00:00
# Subject: Kenvue, Object: IPO, Relationship: INVOLVEDIN, Timestamp: 2023-05-01T00:00:00
# Subject: Kenvue, Object: Reverse_Transition_Manufacturing_Agreement, Relationship: ENTEREDINTO, Timestamp: 2023-07-03T00:00:00
# Subject: Kenvue, Object: Annual_Meeting, Relationship: HOSTS, Timestamp: 2024-03-25T00:00:00
# Subject: Annual_Meeting, Object: May_23_2024, Relationship: SCHEDULEDON, Timestamp: 2024-05-23T09:00:00
# Subject: Kenvue_Inc, Object: id_2023_10_26, Relationship: REPORTEDEARNINGS, Timestamp: 2023-10-26T00:00:00
# Subject: Kenvue, Object: id_1_5, Relationship: IMPACTSRETURN, Timestamp: 2023-07-31T00:00:00

# %% [markdown]
# ## Parameters Investigation.
#
# - `max_characters`: The maximum number of characters in a chunk.
# - `model`: The model to use for the knowledge graph agent. (TogetherAI or Samba Verse)

# %%
elements = uio.parse_file_or_url(str(example_pdf_files[0]))
print(
    colorama.Fore.YELLOW
    + "The number of elements is: "
    + colorama.Fore.RESET
    + str(len(elements))
)

# Investigation of the chunk_elements function.
for max_characters in [512, 1024, 2048]:
    chunk_elements = uio.chunk_elements(
        elements,
        chunk_type="chunk_by_title",
        max_characters=max_characters,
    )
    print(
        colorama.Fore.BLUE
        + f"[max_characters: {max_characters:>4}] "
        + colorama.Fore.YELLOW
        + f"The number of chunk elements is: {len(chunk_elements)}"
        + colorama.Fore.RESET
    )
# Out:
# The number of elements is: 108
# [max_characters:  512] The number of chunk elements is: 26
# [max_characters: 1024] The number of chunk elements is: 13
# [max_characters: 2048] The number of chunk elements is: 7

# %%
limited_chunk_elements = uio.chunk_elements(
    elements, chunk_type="chunk_by_title", max_characters=1000
)
print(len(limited_chunk_elements))
print(limited_chunk_elements[0].text)
# Out:
# 13
# Kenvue Inc. (KVUE)
#
# Updated November 8th, 2024 by Nathan Parsh Key Metrics
#
# Current Price: $23.48 5 Year CAGR Estimate: -0.3% Market Cap: $45 B Fair Value Price: $16.10 5 Year Growth Estimate: 3.0% Ex-Dividend Date: 11/13/24 % Fair Value: 146% 5 Year Valuation Multiple Estimate: -7.3% Dividend Payment Date: 11/27/24 Dividend Yield: 3.5% 5 Year Price Target $19 Years Of Dividend Growth: 62 Dividend Risk Score: A Retirement Suitability Score: A Rating: Sell

# %%
print(len(limited_chunk_elements[0].text))
print(limited_chunk_elements[0].text)
# Out:
# 459
# Kenvue Inc. (KVUE)
#
# Updated November 8th, 2024 by Nathan Parsh Key Metrics
#
# Current Price: $23.48 5 Year CAGR Estimate: -0.3% Market Cap: $45 B Fair Value Price: $16.10 5 Year Growth Estimate: 3.0% Ex-Dividend Date: 11/13/24 % Fair Value: 146% 5 Year Valuation Multiple Estimate: -7.3% Dividend Payment Date: 11/27/24 Dividend Yield: 3.5% 5 Year Price Target $19 Years Of Dividend Growth: 62 Dividend Risk Score: A Retirement Suitability Score: A Rating: Sell

# %%
llama_kg_result = llama_405b_kg_agent.run(
    limited_chunk_elements[0], parse_graph_elements=True
)

# %%
print(len(llama_kg_result.nodes))
print(llama_kg_result.nodes)
# Out:
# 17
# [Node(id='Kenvue Inc.', type="Organization', ticker='KVUE", properties={'source': 'agent_created'}), Node(id='Nathan Parsh', type='Person', properties={'source': 'agent_created'}), Node(id='$19.15', type="Price', description='Current Price", properties={'source': 'agent_created'}), Node(id='5.5%', type="Growth Rate', description='5 Year CAGR Estimate", properties={'source': 'agent_created'}), Node(id='$37 B', type='Market Capitalization', properties={'source': 'agent_created'}), Node(id='$17.78', type="Price', description='Fair Value Price", properties={'source': 'agent_created'}), Node(id='3.0%', type="Growth Rate', description='5 Year Growth Estimate", properties={'source': 'agent_created'}), Node(id='11/07/23', type="Date', description='Ex-Dividend Date", properties={'source': 'agent_created'}), Node(id='108%', type="Valuation', description='% Fair Value", properties={'source': 'agent_created'}), Node(id='-1.5%', type="Valuation Multiple', description='5 Year Valuation Multiple Estimate", properties={'source': 'agent_created'}), Node(id='11/22/23', type="Date', description='Dividend Payment Date", properties={'source': 'agent_created'}), Node(id='4.2%', type='Dividend Yield', properties={'source': 'agent_created'}), Node(id='$21', type="Price', description='5 Year Price Target", properties={'source': 'agent_created'}), Node(id='61', type='Years Of Dividend Growth', properties={'source': 'agent_created'}), Node(id='C', type='Dividend Risk Score', properties={'source': 'agent_created'}), Node(id='B', type='Retirement Suitability Score', properties={'source': 'agent_created'}), Node(id='Hold', type='Rating', properties={'source': 'agent_created'})]

# %%
together_kg_result = together_kg_agent.run(
    limited_chunk_elements[0], parse_graph_elements=True
)

# %%
print(len(together_kg_result.nodes))
print(together_kg_result.nodes)
# Out:
# 18
# [Node(id='Kenvue Inc.', type='Organization', properties={'source': 'agent_created'}), Node(id='Nathan Parsh', type='Person', properties={'source': 'agent_created'}), Node(id='$19.15', type='Price', properties={'source': 'agent_created'}), Node(id='5.5%', type='CAGR', properties={'source': 'agent_created'}), Node(id='$37 B', type='MarketCap', properties={'source': 'agent_created'}), Node(id='$17.78', type='FairValuePrice', properties={'source': 'agent_created'}), Node(id='3.0%', type='GrowthEstimate', properties={'source': 'agent_created'}), Node(id='11/07/23', type='ExDividendDate', properties={'source': 'agent_created'}), Node(id='108%', type='FairValue', properties={'source': 'agent_created'}), Node(id='-1.5%', type='ValuationMultipleEstimate', properties={'source': 'agent_created'}), Node(id='11/22/23', type='DividendPaymentDate', properties={'source': 'agent_created'}), Node(id='4.2%', type='DividendYield', properties={'source': 'agent_created'}), Node(id='$21', type='PriceTarget', properties={'source': 'agent_created'}), Node(id='61', type='YearsOfDividendGrowth', properties={'source': 'agent_created'}), Node(id='C', type='DividendRiskScore', properties={'source': 'agent_created'}), Node(id='B', type='RetirementSuitabilityScore', properties={'source': 'agent_created'}), Node(id='Hold', type='Rating', properties={'source': 'agent_created'}), Node(id='{self.id}', type='{self.type}', properties={'source': 'agent_created'})]

# %% [markdown]
# ## 🌟 Highlights

# %% [markdown]
# This notebook has guided you through setting up and running a dynamic knowledge graph construction workflow using CAMEL's Knowledge Graph Agent and Neo4j. You can adapt and expand this example for various other scenarios requiring dynamic graph generation and querying.
#
# Key tools utilized in this notebook include:
#
# - **CAMEL**: A powerful multi-agent framework that enables the construction of knowledge graphs from unstructured data.
# - **Neo4j**: A graph database used to store and query the knowledge graph.
# - **Together and SambaVerse Models**: Large language models used to generate the knowledge graph from parsed documents.
# - **Deduplication**: Techniques to ensure the uniqueness of nodes and relationships in the graph.
#
# This comprehensive setup allows you to adapt and expand the example for various scenarios requiring dynamic graph generation and querying.

# %% [markdown]
# <div class="align-center">
#   <a href="https://www.camel-ai.org/"><img src="https://i.postimg.cc/KzQ5rfBC/button.png"width="150"></a>
#   <a href="https://discord.camel-ai.org"><img src="https://i.postimg.cc/L4wPdG9N/join-2.png"  width="150"></a></a>
#
# ⭐ <i>Star us on [*Github*](https://github.com/camel-ai/camel), join our [*Discord*](https://discord.camel-ai.org) or follow our [*X*](https://x.com/camelaiorg)
# </div>
